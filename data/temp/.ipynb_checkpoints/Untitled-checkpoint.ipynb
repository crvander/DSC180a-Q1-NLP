# %%
import pandas as pd

# %%
pd.read_csv('test.csv').head(50)
# Out:
#                                                  text  labels
# 0   The dividends payable annually shall be deduct...       0
# 1   RT @realJosephRich: Tim Cook furiously trying ...       1
# 2   Stora Enso 's business in North America has an...       0
# 3   Operating profit totaled EUR 825mn , up from E...       1
# 4    Come fly with me, let?s fly, let?s fly away ! al       1
# 5   BAC Out of my short for  Should go around 12.0...      -1
# 6   AMZN flagging.A clearance of this flag will op...       1
# 7   SWY pretty lame selling SWY because WMT sold h...       1
# 8   user: Anyone like V? ooks bullish here, needs ...       1
# 9         AEE crosses below 34, and I am shorting it.      -1
# 10  Trading in the new shares , which have right t...       0
# 11  $spy $spx $ES_F if markets base on weekly char...       1
# 12  user I lost 15% of my holdings when it first o...       1
# 13  E 's building system service had revenue of EU...       0
# ...
